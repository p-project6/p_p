# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import signal
from heartpy import filter_signal
import os
import shutil
# Out:
# In C:\Users\ohsu\anaconda3\envs\tensorflow\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The text.latex.preview rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Users\ohsu\anaconda3\envs\tensorflow\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Users\ohsu\anaconda3\envs\tensorflow\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
# In C:\Users\ohsu\anaconda3\envs\tensorflow\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The validate_bool_maybe_none function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# ...

# %% [markdown]
# ### *데이터overlap

# %%
for j in range(1,101):
    for k in range(1,61):
        list=pd.DataFrame()
        if os.path.exists("dataDivision/band/{}/{}".format(j,k,i+1)):
            os.makedirs('dataDivision_1s_over/band/{}/{}'.format(j,k), exist_ok=True)
            for i in range(1,7):
                a = pd.read_csv("dataDivision/band/{}/{}/{}.csv".format(j,k,i), header=None)
                list = list.append(a)
                
            list.reset_index(inplace=True, drop=True)
            for l in range (0,6):
                num=128*l
                b=list.truncate(before=num, after=num+255, axis=0)
                b.to_csv('dataDivision_1s_over/band/{}/{}/{}.csv'.format(j,k,l+1), index=False, header=False)

# %%
for j in range(1,101):
    for k in range(1,61):
        list=pd.DataFrame()
        if os.path.exists("dataDivision/high/{}/{}".format(j,k,i+1)):
            os.makedirs('dataDivision_1s_over/high/{}/{}'.format(j,k), exist_ok=True)
            for i in range(1,7):
                a = pd.read_csv("dataDivision/high/{}/{}/{}.csv".format(j,k,i), header=None)
                list = list.append(a)
                
            list.reset_index(inplace=True, drop=True)
            for l in range (0,6):
                num=128*l
                b=list.truncate(before=num, after=num+255, axis=0)
                b.to_csv('dataDivision_1s_over/high/{}/{}/{}.csv'.format(j,k,l+1), index=False, header=False)

# %%
for j in range(1,101):
    for k in range(1,61):
        list=pd.DataFrame()
        if os.path.exists("dataDivision/low/{}/{}".format(j,k,i+1)):
            os.makedirs('dataDivision_1s_over/low/{}/{}'.format(j,k), exist_ok=True)
            for i in range(1,7):
                a = pd.read_csv("dataDivision/low/{}/{}/{}.csv".format(j,k,i), header=None)
                list = list.append(a)
                
            list.reset_index(inplace=True, drop=True)
            for l in range (0,6):
                num=128*l
                b=list.truncate(before=num, after=num+255, axis=0)
                b.to_csv('dataDivision_1s_over/low/{}/{}/{}.csv'.format(j,k,l+1), index=False, header=False)

# %%
list=pd.DataFrame()
for i in range(1,7):
            a = pd.read_csv("dataDivision/band/1/2/{}.csv".format(i), header=None)
            list = list.append(a)
            list.reset_index(inplace=True, drop=True)
            
list
# Out:
#              0
# 0     0.053295
# 1     0.053439
# 2     0.055066
# 3     0.059409
# 4     0.067278
# ...        ...
# 1531 -0.100452
# 1532 -0.100579
# 1533 -0.101653
# 1534 -0.103329
# 1535 -0.105151
#
# [1536 rows x 1 columns]

# %%
list.loc[895]
# Out:
# 0   -0.040261
# Name: 895, dtype: float64

# %% [markdown]
# ### *데이터분리/통합

# %% [markdown]
# - band

# %%
total=pd.DataFrame()
for j in range(1,101):
    arr = np.array([])
    for l in range(360):
        arr = np.append(arr, np.array([j]))
    list=pd.DataFrame()
    for k in range(1,61):
        for i in range(1,7):
            a = pd.read_csv("dataDivision_1s_over/band/{}/{}/{}.csv".format(j,k,i), header=None)
            a=a.transpose()
            list = list.append(a)
            
    list[256]=arr
    list.reset_index(inplace=True, drop=True)
    total=total.append(list)
total.reset_index(inplace=True, drop=True)

# %%
total
# Out:
#             0         1         2         3         4         5         6    \
# 0     -0.031820 -0.015874 -0.001172  0.011249  0.020713  0.026974  0.030190
# 1      0.401977  0.381335  0.353735  0.319320  0.278790  0.233424  0.184983
# 2     -0.019872 -0.020594 -0.021637 -0.022515 -0.022798 -0.022202 -0.020644
# 3      0.400917  0.403804  0.402367  0.396151  0.384771  0.367941  0.345523
# 4     -0.057454 -0.056822 -0.055984 -0.054985 -0.053945 -0.052999 -0.052250
# ...         ...       ...       ...       ...       ...       ...       ...
# 35995 -0.050435 -0.047843 -0.044973 -0.042221 -0.040007 -0.038694 -0.038512
# 35996  0.022090  0.024929  0.027786  0.031100  0.035075  0.039622  0.044402
# 35997 -0.041365 -0.039069 -0.036238 -0.033035 -0.029705 -0.026536 -0.023804
# 35998 -0.079288 -0.083358 -0.086464 -0.087995 -0.087513 -0.084880 -0.080336
# 35999 -0.066587 -0.039245 -0.021757 -0.013691 -0.013089 -0.017145 -0.022893
#
# ...

# %%
total.to_csv('model_1s_over/total_band.csv', index=False, header=False)

# %% [markdown]
# - high

# %%
total=pd.DataFrame()
for j in range(1,101):
    arr = np.array([])
    for l in range(360):
        arr = np.append(arr, np.array([j]))
    list=pd.DataFrame()
    for k in range(1,61):
        for i in range(1,7):
            a = pd.read_csv("dataDivision_1s_over/high/{}/{}/{}.csv".format(j,k,i), header=None)
            a=a.transpose()
            list = list.append(a)
            
    list[256]=arr
    list.reset_index(inplace=True, drop=True)
    total=total.append(list)
total.reset_index(inplace=True, drop=True)

# %%
total
# Out:
#             0         1         2         3         4         5         6    \
# 0     -0.011566  0.077466  0.083038  0.015121 -0.024216  0.026618  0.112943
# 1      0.333165  0.386996  0.454338  0.324952  0.235537  0.246562  0.251469
# 2     -0.105411  0.006199  0.035219 -0.038238 -0.087385 -0.047431  0.057264
# 3      0.354916  0.394712  0.453208  0.405614  0.339571  0.334389  0.367986
# 4     -0.124635 -0.101820 -0.004986 -0.009573 -0.097080 -0.078287 -0.033934
# ...         ...       ...       ...       ...       ...       ...       ...
# 35995 -0.012444 -0.030325 -0.013896 -0.007077 -0.017446 -0.022156 -0.026465
# 35996  0.020267  0.062224 -0.014968  0.012301  0.073691  0.025622  0.056645
# 35997 -0.018143 -0.060154 -0.043685 -0.038534 -0.053733  0.003980 -0.039076
# 35998 -0.091136 -0.072359 -0.082491 -0.096773 -0.108624 -0.106044 -0.096813
# 35999 -0.068907 -0.061061 -0.045704 -0.016907 -0.031589 -0.047582 -0.016614
#
# ...

# %%
total.to_csv('model_1s_over/total_high.csv', index=False, header=False)

# %% [markdown]
# - low

# %%
total=pd.DataFrame()
for j in range(1,101):
    arr = np.array([])
    for l in range(360):
        arr = np.append(arr, np.array([j]))
    list=pd.DataFrame()
    for k in range(1,61):
        for i in range(1,7):
            a = pd.read_csv("dataDivision_1s_over/low/{}/{}/{}.csv".format(j,k,i), header=None)
            a=a.transpose()
            list = list.append(a)
            
    list[256]=arr
    list.reset_index(inplace=True, drop=True)
    total=total.append(list)
total.reset_index(inplace=True, drop=True)

# %%
total
# Out:
#             0         1         2         3         4         5         6    \
# 0      1.697478  1.713703  1.728594  1.741144  1.750717  1.757105  1.760490
# 1      2.157222  2.136746  2.109318  2.075073  2.034710  1.989504  1.941220
# 2      1.748610  1.747925  1.746924  1.746097  1.745874  1.746535  1.748158
# 3      2.170759  2.173616  2.172147  2.165900  2.154489  2.137630  2.115185
# 4      1.709674  1.710317  1.711171  1.712183  1.713227  1.714166  1.714897
# ...         ...       ...       ...       ...       ...       ...       ...
# 35995  1.566146  1.568872  1.571868  1.574740  1.577074  1.578513  1.578830
# 35996  1.656066  1.659062  1.662113  1.665637  1.669814  1.674541  1.679471
# 35997  1.606899  1.609297  1.612236  1.615546  1.618973  1.622223  1.625016
# 35998  1.575260  1.571225  1.568130  1.566590  1.567050  1.569659  1.574187
# 35999  1.585412  1.612532  1.629898  1.637959  1.638663  1.634776  1.629212
#
# ...

# %%
total.to_csv('model_1s_over/total_low.csv', index=False, header=False)
